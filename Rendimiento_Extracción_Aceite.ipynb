# %% [markdown]
# <a href="https://colab.research.google.com/github/jesusnarvarz3-droid/Notebook_Agro_2026_1/blob/main/Rendimiento_Extracci%C3%B3n_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Control de Rendimiento en Extracción de Aceite**
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el **peso total de los racimos de fruta fresca (RFF)** procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float). (pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float).(lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L(r)
# .
#
# $$pa =lt * 0.92$$
# $$r=(pr) * 100$$
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRAD: Solicitar el nombre del lote de producción (Tipo string).
#Solicitar el peso de los racimos en kg (Tipo float). (pr)
#solicitar los litros de aceite obtenidos (Tipo float).(lt)
nombre = input("Ingrese el nombre del lote: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))

#PROCES: calcular el peso del aceite (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa / pr) * 100

#SALIDA: informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: el perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese la cantidad de aceite crudo obtenido en litros: 200
# El rendimiento del lote el perico es del 18.4 %

# %% [markdown]
# A continuación, se presenta una explicación detallada de cada línea del código proporcionado:
#
# ```python
# # ENTRAD: Solicitar el nombre del lote de producción (Tipo string).
# #Solicitar el peso de los racimos en kg (Tipo float). (pr)
# #solicitar los litros de aceite obtenidos (Tipo float).(lt)
# nombre = input("Ingrese el nombre del lote: ")
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))
#
# #PROCES: calcular el peso del aceite (pa) y el rendimiento (r)
# pa = lt * 0.92
# r = (pa / pr) * 100
#
# #SALIDA: informar el rendimiento del lote
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
#
# **Explicación Línea por Línea:**
#
# 1.  `# ENTRAD: Solicitar el nombre del lote de producción (Tipo string).`
#     *   Esta es una línea de comentario que indica la sección de **ENTRADA** de datos. Explica que se solicitará el nombre del lote, el cual debe ser un tipo de dato string (cadena de texto).
#
# 2.  `#Solicitar el peso de los racimos en kg (Tipo float). (pr)`
#     *   Otra línea de comentario, indicando que se solicitará el peso de los racimos (representado por la variable `pr`), el cual debe ser un número con decimales (float) y estar en kilogramos.
#
# 3.  `#solicitar los litros de aceite obtenidos (Tipo float).(lt)`
#     *   Comentario que especifica la solicitud de la cantidad de aceite obtenida en litros (variable `lt`), que también será un número con decimales (float).
#
# 4.  `nombre = input("Ingrese el nombre del lote: ")`
#     *   Esta línea solicita al usuario que ingrese el nombre del lote de producción. La función `input()` muestra el mensaje "Ingrese el nombre del lote: " en la consola y espera a que el usuario escriba un valor y presione Enter. El valor ingresado se guarda como una cadena de texto en la variable `nombre`.
#
# 5.  `pr = float(input("Ingrese el peso de los racimos en kg: "))`
#     *   Aquí se solicita al usuario el peso de los racimos en kilogramos. Similar a la línea anterior, `input()` muestra el mensaje. Sin embargo, en este caso, la entrada del usuario se convierte inmediatamente a un número de punto flotante (decimal) usando `float()` antes de ser asignada a la variable `pr`. Esto es crucial para poder realizar cálculos matemáticos con este valor.
#
# 6.  `lt = float(input("Ingrese la cantidad de aceite crudo obtenido en litros: "))`
#     *   De manera análoga a la línea anterior, esta línea solicita al usuario la cantidad de aceite obtenido en litros. La entrada del usuario se convierte a un número de punto flotante (decimal) con `float()` y se almacena en la variable `lt`.
#
# 7.  `#PROCES: calcular el peso del aceite (pa) y el rendimiento (r)`
#     *   Comentario que delimita la sección de **PROCESAMIENTO** de los datos. Indica que se calcularán el peso del aceite (`pa`) y el rendimiento (`r`).
#
# 8.  `pa = lt * 0.92`
#     *   Esta línea realiza el cálculo del **peso del aceite (pa)**. Multiplica la cantidad de aceite en litros (`lt`) por su densidad aproximada (0.92 kg/L) para obtener el peso del aceite en kilogramos.
#
# 9.  `r = (pa / pr) * 100`
#     *   Esta línea calcula el **Índice de Rendimiento de Extracción (r)**. Divide el peso del aceite obtenido (`pa`) por el peso total de los racimos procesados (`pr`) y luego multiplica el resultado por 100 para expresarlo como un porcentaje.
#
# 10. `#SALIDA: informar el rendimiento del lote`
#     *   Comentario que marca la sección de **SALIDA** del programa, donde se mostrarán los resultados al usuario.
#
# 11. `print("El rendimiento del lote", nombre, "es del", r, "%")`
#     *   Esta es la línea de salida que muestra el resultado final al usuario. Utiliza la función `print()` para concatenar y mostrar una cadena de texto informativa. Incluye el nombre del lote (`nombre`) y el rendimiento calculado (`r`), seguido de un símbolo de porcentaje, presentando el resultado de una manera clara y legible.
